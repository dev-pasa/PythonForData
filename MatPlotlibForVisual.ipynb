# %% [markdown]
# Import Matplotlib and create x, y variables.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# Import Package numpy. Numpy supports large, multi-dimensional arrays and matrices.

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, 'r-')
plt.xlabel('X Label')
plt.ylabel('Y Label')
# Out:
# Text(0, 0.5, 'Y Label')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
## 00
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y,'b')
axes.set_xlabel('Set X Label')
axes.set_ylabel('Set y Lable')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, .8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

#Larger Figure Axes 1
axes1.plot(x,y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y,x,'r')

# %%
fig, axes = plt.subplots()

axes.plot(x,y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018A7EE52550>,
# ...
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x,y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    
fig

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

for ax in axes:
    ax.plot(x,y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
fig
plt.tight_layout()

# %%
fig = plt.figure(figsize = (8,4), dpi= 100)

# %%
fig, axes = plt.subplots(figsize=(12,13))
axes.plot(x,y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig.savefig("filename.png")

# %%
fig.savefig("filename.png", dpi=200)

# %%
ax.set_title('title');

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="y**2")
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="y**3")
ax.legend()

# %%
ax.legend(loc=1)
ax.legend(loc=2)
ax.legend(loc=3)
ax.legend(loc=4)

ax.legend(loc=0)
fig

# %%
fig, ax= plt.subplots()
ax.plot(x, x**2, 'b.--')
ax.plot(x, x**3, 'g--')

# %%
fig, ax = plt.subplots()
ax.plot(x, x+1, color="blue", alpha=0.5)
ax.plot(x, x+2, color="#8B008B")
ax.plot(x, x+3, color="#FF8C00")

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth= 0.25)
ax.plot(x, x+2, color="red", linewidth= 0.50)
ax.plot(x, x+3, color="red", linewidth= 1.00)
ax.plot(x, x+4, color="red", linewidth= 2.00)

# possible linestype options
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')
        
# custom dash
line, = ax.plot(x, x+8, color="black", lw= 1.50)
line.set_dashes([5,10,15, 10]) #format:line length, space length, ...
        
# possbile marker symbols: marker
ax.plot(x, x+9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title("custom axes range");

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([ 9.,  5., 12., 13.,  6., 11., 14.,  5., 10., 15.]),
#  array([  1. ,  98.7, 196.4, 294.1, 391.8, 489.5, 587.2, 684.9, 782.6,
#         880.3, 978. ]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True);

# %%
data = [np.random.normal(0,std,100)for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True);

# %%
data = [np.random.normal(0,std,100)for std in range(1,4)]
plt.boxplot(data, vert = True, patch_artist=True);

# %% [markdown]
# Source: http://www.labri.fr/perso/nrougier/teaching/matplotlib/
# - ** All code and material is licensed under a Creative Commons Attribution-ShareAlike 4.0. **

# %%
import numpy as np
Y = np.linspace(-np.pi, np.pi, 256, endpoint = True)
C,S = np.cos(Y), np.sin(Y)

# %%
plt.plot(Y,C)
plt.plot(Y,S)

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.plot(Y, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(Y, S, color="red",  linewidth=2.5, linestyle="-")

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.plot(Y, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(Y, S, color="red",  linewidth=2.5, linestyle="-")
plt.xlim(Y.min()*1.1, Y.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)
# Out:
# (-1.1, 1.0999165211263138)

# %% [markdown]
# Source: https://matplotlib.org/examples/statistics/histogram_demo_features.html

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

# %%
mu = 100
sigma = 15
x = mu + sigma * np.random.randn(500)
num_bins = 50

# %%
fig, ax = plt.subplots()
n, bins, patches = ax.hist(x, num_bins, density=2)
